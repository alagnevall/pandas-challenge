# %%
#setup and imports
import pandas as pd

# %%
#file to read from
file = "Resources/purchase_data.csv"

#read the files

heros_df = pd.read_csv(file)

# %%
#read first 5 lines of file
heros_df.head()
# heros_df.columns
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#extract the columns to be used
# heroheaders_df = heros_df[['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price']]

# %%
#find the total # of players.  Will need to find unique values since they could be on the list multiple times
heros_df.SN.nunique()
# total_df = pd.DataFrame({"Total Players":total})
# total_df
# Out:
# 576

# %%
# Run basic calculations to obtain number of unique items, average price, etc.
unique_items = (heros_df['Item ID'].nunique())
average_price = (heros_df['Price'].mean())
total_purchases = (heros_df['Purchase ID'].count())
revenue = (heros_df['Price'].sum())
# Create a summary data frame to hold the results
summary_df = pd.DataFrame({"Number of Unique Items":[unique_items],
      "Average Price":average_price,
      "Number of Purchases":total_purchases,
      "Total Revenue":revenue})
# Optional: give the displayed data cleaner formatting

# Display the summary data frame
summary_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %%
# Percentage and Count of Male Players
# Percentage and Count of Female Players
# Percentage and Count of Other / Non-Disclosed

gender_count = heros_df["Gender"].value_counts() #counts are wrong. Need to find UNIQUE players
gender_percentage = heros_df["Gender"].value_counts("%")*100

gender_df = pd.DataFrame({"Total Count":gender_count,
      "Percentage of Players":gender_percentage})
gender_df
# Out:
#                        Total Count  Percentage of Players
# Male                           652              83.589744
# Female                         113              14.487179
# Other / Non-Disclosed           15               1.923077

# %%
# Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
grouped_df = heros_df.groupby(["Gender"])
grouped_df.head()

purchase_count = grouped_df['Purchase ID'].count()
average_price = grouped_df['Price'].mean()
total_purchases = grouped_df['Price'].sum()
avg_tot_purchase = total_purchases/purchase_count


# Create a summary data frame to hold the results
gender_summary_df = pd.DataFrame({"Purchase Count":purchase_count,
      "Average Purchase Price":average_price,
      "Total Purchase Value":total_purchases,
      "Avg Total Purchase":avg_tot_purchase                            
      })
# Optional: give the displayed data cleaner formatting


# Display the summary data frame
gender_summary_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase
# Gender
# Female                               361.94            3.203009
# Male                                1967.64            3.017853
# Other / Non-Disclosed                 50.19            3.346000

# %%
# Establish bins for ages
# print(heros_df.Age.max())
# print(heros_df.Age.min())
bins = [0, 10, 14, 19, 24, 29, 34, 39, 40]
group_names = ["<10","11-14","15-19","20-24","25-29","30-34","35-39","40+"]

# Categorize the existing players using the age bins. Hint: use pd.cut()
heros_df["Age Group"] = pd.cut(heros_df["Age"], bins, labels=group_names, include_lowest = True)

# Calculate the numbers and percentages by age group
age_group = heros_df["Age Group"].value_counts()
age_percentage= heros_df["Age Group"].value_counts("%") * 100

# Create a summary data frame to hold the results
age_group_df = pd.DataFrame({"Total Count":age_group,
      "Percentage of Players":age_percentage})      
age_group_df.sort_values(age_group_df.columns[0])
# df.sort_values(by=['sort','A','B'],inplace=True)

# Optional: round the percentage column to two decimal points


# Display Age Demographics Table
# Out:
#        Total Count  Percentage of Players
# 40+              6               0.776197
# 11-14           19               2.457956
# <10             32               4.139715
# 35-39           41               5.304010
# 30-34           73               9.443726
# 25-29          101              13.065977
# 15-19          136              17.593790
# 20-24          365              47.218629

# %%
# Bin the purchase_data data frame by age
group_age_df = heros_df.groupby(["Age Group"])


# Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
purchase_count = group_age_df['Purchase ID'].count()
average_price = group_age_df['Price'].mean()
total_purchases = group_age_df['Price'].sum()
avg_tot_purchase = total_purchases/purchase_count


# Create a summary data frame to hold the results
age_summary_df = pd.DataFrame({"Purchase Count":purchase_count,
      "Average Purchase Price":average_price,
      "Total Purchase Value":total_purchases,
      "Avg Total Purchase":avg_tot_purchase                            
      })

# Optional: give the displayed data cleaner formatting


# Display the summary data frame
age_summary_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                    32                3.405000                108.96
# 11-14                  19                2.681579                 50.95
# 15-19                 136                3.035956                412.89
# 20-24                 365                3.052219               1114.06
# 25-29                 101                2.900990                293.00
# 30-34                  73                2.931507                214.00
# 35-39                  41                3.601707                147.67
# 40+                     6                2.785000                 16.71
#
#            Avg Total Purchase
# Age Group
# <10                  3.405000
# 11-14                2.681579
# 15-19                3.035956
# 20-24                3.052219
# 25-29                2.900990
# 30-34                2.931507
# 35-39                3.601707
# 40+                  2.785000

# %%
# Run basic calculations to obtain the results in the table below
top_spender_df = heros_df.groupby(["SN"])


purchase_count = top_spender_df['Purchase ID'].count()
average_price = top_spender_df['Price'].mean()
total_purchases = top_spender_df['Price'].sum()

# Create a summary data frame to hold the results
top_spender_summary_df = pd.DataFrame({"Purchase Count":purchase_count,
      "Average Purchase Price":average_price,
      "Total Purchase Value":total_purchases,})


# Sort the total purchase value column in descending order
# Optional: give the displayed data cleaner formatting
# Display a preview of the summary data frame

top_spender_summary_df.sort_values("Total Purchase Value", ascending = False).head()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
# Retrieve the Item ID, Item Name, and Item Price columns
popular_item_df = heros_df.groupby(["Item ID","Item Name"])


purchase_count = popular_item_df['Purchase ID'].count()
price = popular_item_df['Price'].mean()
total_purchases = popular_item_df['Price'].sum()


# Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value


# Create a summary data frame to hold the results
popular_item_df = pd.DataFrame({"Purchase Count":purchase_count,
      "Item Price":price,
      "Total Purchase Value":total_purchases,})

# Sort the purchase count column in descending order


# Optional: give the displayed data cleaner formatting


# Display a preview of the summary data frame
popular_item_df.sort_values("Purchase Count", ascending = False).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 145     Fiery Glass Crusader                            4.580000
# 132     Persuasion                                      3.221111
# 108     Extraction, Quickblade Of Trembling Hands       3.530000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
# Sort the above table by total purchase value in descending order
popular_item_df.sort_values("Total Purchase Value", ascending = False).head()

# Optional: give the displayed data cleaner formatting


# Display a preview of the data frame
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
